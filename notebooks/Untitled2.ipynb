# %%
import pandas as pd
import numpy as np
import datetime as dt

import matplotlib.pyplot as plt
import seaborn as sns

from droughts_modelling.data import DataFunctions

pd.options.display.max_columns = 99

# %%
DataFunctions().light_weekly_aggregate()
# Out:
#          fips_  year_  week_num_  PRECTOT_mean     PS_mean  QV2M_mean  \
# 0         1001   2000          1      5.261429  100.702857   6.491429
# 1         1001   2000          2      3.554286  101.100000   6.104286
# 2         1001   2000          3      4.017143  100.348571   6.090000
# 3         1001   2000          4      3.742857  100.755714   3.072857
# 4         1001   2000          5      0.000000  101.012857   3.142857
# ...        ...    ...        ...           ...         ...        ...
# 2759898  56043   2016         48      0.211429   82.517143   2.265714
# 2759899  56043   2016         49      0.624286   82.787143   1.841429
# 2759900  56043   2016         50      0.754286   82.602857   1.574286
# 2759901  56043   2016         51      0.775714   82.742857   2.201429
# 2759902  56043   2016         52      0.326667   82.945000   1.750000
#
#           T2M_mean  T2MDEW_mean  T2MWET_mean  T2M_MAX_mean  T2M_MIN_mean  \
# 0         9.878571     5.648571     5.674286     16.345714      3.647143
# 1         9.662857     5.527143     5.552857     16.751429      2.928571
# 2         8.270000     4.834286     4.890000     13.738571      2.795714
# 3         0.737143    -3.367143    -3.265714      5.570000     -3.320000
# 4         2.501429    -2.685714    -2.627143     10.460000     -3.842857
# ...            ...          ...          ...           ...           ...
# 2759898  -3.541429    -9.130000    -9.007143      0.507143     -7.105714
# 2759899  -8.072857   -12.847143   -12.498571     -3.115714    -12.475714
# 2759900 -10.298571   -14.704286   -14.268571     -4.091429    -15.560000
# 2759901  -5.717143    -9.964286    -9.821429      0.598571    -11.361429
# 2759902  -7.315000   -12.325000   -12.048333     -0.335000    -12.181667
#
#          T2M_RANGE_mean    TS_mean  WS10M_mean  WS10M_MAX_mean  \
# 0             12.698571   9.397143    2.630000        3.722857
# 1             13.825714   9.431429    2.472857        3.585714
# 2             10.941429   8.194286    2.507143        3.574286
# 3              8.890000   0.817143    2.774286        3.908571
# 4             14.301429   2.021429    2.211429        3.161429
# ...                 ...        ...         ...             ...
# 2759898        7.614286  -4.108571    4.227143        6.260000
# 2759899        9.361429  -8.557143    3.268571        5.190000
# 2759900       11.467143 -11.231429    3.212857        5.612857
# 2759901       11.960000  -7.302857    4.641429        6.664286
# 2759902       11.846667  -9.206667    4.590000        6.711667
#
#          WS10M_MIN_mean  WS10M_RANGE_mean  WS50M_mean  WS50M_MAX_mean  \
# 0              1.520000          2.201429    5.044286        6.934286
# 1              1.568571          2.018571    5.142857        7.162857
# 2              1.461429          2.110000    4.702857        6.682857
# 3              1.664286          2.248571    4.928571        6.727143
# 4              1.225714          1.934286    4.125714        5.971429
# ...                 ...               ...         ...             ...
# 2759898        2.197143          4.057143    6.231429        8.827143
# 2759899        1.485714          3.704286    4.784286        7.161429
# 2759900        1.051429          4.561429    4.600000        7.524286
# 2759901        2.394286          4.268571    6.905714        9.538571
# 2759902        2.478333          4.235000    6.828333        9.515000
#
#          WS50M_MIN_mean  WS50M_RANGE_mean  score_max
# 0              2.815714          4.120000        1.0
# 1              2.968571          4.192857        2.0
# 2              2.997143          3.685714        2.0
# 3              3.244286          3.480000        2.0
# 4              2.045714          3.927143        1.0
# ...                 ...               ...        ...
# 2759898        3.687143          5.140000        0.0
# 2759899        2.328571          4.831429        0.0
# 2759900        1.565714          5.957143        0.0
# 2759901        4.108571          5.428571        0.0
# 2759902        4.071667          5.443333        0.0
#
# [2759903 rows x 22 columns]

# %%
DataFunctions().tree_feature_importance()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/kh/fd0llhc91_s537ztm8vty5q00000gn/T/ipykernel_14434/3449550487.py in <module>
# ----> 1 DataFunctions().tree_feature_importance()
#
# ~/.pyenv/versions/3.8.6/envs/droughts/lib/python3.8/site-packages/droughts_modelling/data.py in tree_feature_importance(self)
#     122
#     123     def tree_feature_importance(self):
# --> 124         df = DataFunctions().light_weekly_aggregate(self)
#     125
#     126         y = round(df['score_max'])
#
# TypeError: light_weekly_aggregate() takes 1 positional argument but 2 were given
