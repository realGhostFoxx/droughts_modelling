# %%
import os
import pandas as pd
import numpy as np
import datetime as dt

import seaborn as sns
import matplotlib.pyplot as plt

from droughts_modelling.data import train_last_2_years

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
yr2_df = train_last_2_years()

# %%
yr2_df.head()
# Out:
#       fips       date  PRECTOT      PS   QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# 5479  1001 2015-01-01     7.15  101.11   4.93   6.21    3.44    3.45    13.71
# 5480  1001 2015-01-02    11.08  100.80   7.39   9.99    9.43    9.43    12.54
# 5481  1001 2015-01-03    24.03  100.26  11.56  16.54   15.95   15.95    21.33
# 5482  1001 2015-01-04    31.32  100.82   7.58  11.56    9.09    9.09    18.82
# 5483  1001 2015-01-05     0.00  101.75   3.26   3.19   -1.99   -1.93     9.06
#
#       T2M_MIN  ...     TS  WS10M  WS10M_MAX  WS10M_MIN  WS10M_RANGE  WS50M  \
# 5479    -0.49  ...   6.30   1.34       2.27       0.27         2.00   2.70
# 5480     6.77  ...  10.00   1.93       2.68       1.30         1.38   3.80
# 5481    11.17  ...  16.50   3.65       4.50       2.50         2.01   6.78
# 5482     4.90  ...  11.43   2.84       4.12       1.50         2.62   5.31
# 5483    -0.03  ...   2.94   2.61       3.73       1.66         2.07   4.60
#
#       WS50M_MAX  WS50M_MIN  WS50M_RANGE  score
# 5479       4.85       0.39         4.46    NaN
# 5480       5.49       2.26         3.23    NaN
# 5481       8.29       4.95         3.34    NaN
# 5482       6.54       3.26         3.28    NaN
# 5483       5.78       3.04         2.74    NaN
#
# [5 rows x 21 columns]

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(yr2_df.corr(), 
            annot=True, 
            cmap="YlGnBu",
           linewidths=.5)
# Out:
# <AxesSubplot:>
